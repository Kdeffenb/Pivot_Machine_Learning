# %% [markdown]
# # ML10 Group Project Outline

# %% [markdown]
# <a name="Contents"></a>
# ## Table of Contents
# * [Project Introduction](#Intro)
# * [Obtain the Data](#Obtain)
# * [Data Dictionary](#Dictionary)
# * [Focus on Questions](#Focus)
# * [Data Exploration](#Explore)
# * [Continue the Exploration](#Continue)
# * [Initial Visualizations](#Visualizations)
# * [Revisit your Basic Questions](#Basic)
# * [Revisit your Prediction Problems](#Prediction)
# * [Seaborn Pairplots](#Seaborn)
# * [Machine Learning](#ML)
# * [Regression](#Regression)
# * [Classification](#Classification)
# * [Communicate the Results](#Results)

# %% [markdown]
# <a name="Intro"></a>
# ## Project Introduction
#
# Give a brief description of your dataset followed by the primary questions you plan to explore. Finally, talk about the various audiences you will keep in mind throughout your exploration.
#
# Note: After giving some thought to the 'Questions' over the weekend, I have come to the following decision ...
# * You will need to have two Prediction Problems, one of which is the prediction of a continuous/measurable Target based upon other Features of the dataset. The other is the prediction of a categorical Target (again) based upon other Features of the dataset.
#
# * You will also need to have 2-3 Basic Questions which come from your curiosity of the data, and hopefully questions with answers that would benefit your key audiences as well.
#
# # Customer Personality Analysis is a detailed analysis of a company’s ideal customers. It helps a business to better understand its customers and makes it easier for them to modify products according to the specific needs, behaviors and concerns of different types of customers.
#
# # I predict that the amount of wine purchased can help determine if there are children in the home.
#
# #I Predict that the amount of wine purchased and/or the total purchases will indicate the income of the customer.
#
# # Do people born before 1970 avoid shopping online?
#
# # Which type of customer takes the most advantage of deals?
#
#
#
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# <a name="Obtain"></a>
# ## Obtain the Data
#
# * Upload your dataset into your notebook.
#
# **With Colab** ... use
#
# google.colab import files
#
# uploaded = files.upload()
#
# **With Anaconda ...**
# If the file is in your current directory, simply read it into a dataframe.
# If not, you can change your directory with cd path-to-desired-directory ... or ...
# you can place the path-to-desired-directory/filename in your filename to pull the file into a dataframe
#
# * Import pandas ... and  pull your dataset into a dataframe.
#
# * View the first (or a sample) of rows.
#
# * Show the columns
#
#
# [Back to Table of Contents](#Contents)

# %%
# Upload your dataset

# Import Python packages for the data exploration to follow

# Create the intial dataframe from your dataset

# View the a few columns from the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-bab11c37-a697-4fa4-b509-1758fae6b615" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bab11c37-a697-4fa4-b509-1758fae6b615">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving marketing_campaign.csv to marketing_campaign.csv

# %%
# Show the columns of the dataframe
df = pd.read_csv('marketing_campaign.csv', sep='\t')
df
# Out:
#          ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0      5524        1957  Graduation  ...             3         11         1
# 1      2174        1954  Graduation  ...             3         11         0
# 2      4141        1965  Graduation  ...             3         11         0
# 3      6182        1984  Graduation  ...             3         11         0
# 4      5324        1981         PhD  ...             3         11         0
# ...     ...         ...         ...  ...           ...        ...       ...
# 2235  10870        1967  Graduation  ...             3         11         0
# 2236   4001        1946         PhD  ...             3         11         0
# 2237   7270        1981  Graduation  ...             3         11         0
# 2238   8235        1956      Master  ...             3         11         0
# 2239   9405        1954         PhD  ...             3         11         1
#
# [2240 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %% [markdown]
# <a name="Dictionary"></a>
# ## Create a Data Dictionary
# (See Notebook #1, your Kaggle Data Site, and conversations with your breakout group.)
#
# * For each of the columns, indicate the data type contained along with a brief description.
#
# * Give the source/origin of the data
#
# * Brief overview of the contents
#
# * Offer any additional info that would be beneficial to the reader
#
# * Suggest other related data that could be helpful and/or other questions for investigation
#
#
# # Data Dictionary
#
# People
#
# ID: Customer's unique identifier
#
# Year_Birth: Customer's birth year
#
# Education: Customer's education level
#
# Marital_Status: Customer's marital status
#
# Income: Customer's yearly household income
#
# Kidhome: Number of children in customer's household
#
# Teenhome: Number of teenagers in customer's household
#
# Dt_Customer: Date of customer's enrollment with the company
#
# Recency: Number of days since customer's last purchase
#
# Complain: 1 if customer complained in the last 2 years, 0 otherwise
#
#
# Products
#
# MntWines: Amount spent on wine in last 2 years
#
# MntFruits: Amount spent on fruits in last 2 years
#
# MntMeatProducts: Amount spent on meat in last 2 years
#
# MntFishProducts: Amount spent on fish in last 2 years
#
# MntSweetProducts: Amount spent on sweets in last 2 years
#
# MntGoldProds: Amount spent on gold in last 2 years
#
#
# Promotion
#
# NumDealsPurchases: Number of purchases made with a discount
#
# AcceptedCmp1: 1 if customer accepted the offer in the 1st campaign, 0 otherwise
#
# AcceptedCmp2: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
#
# AcceptedCmp3: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
#
# AcceptedCmp4: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
#
# AcceptedCmp5: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
#
# Response: 1 if customer accepted the offer in the last campaign, 0 otherwise
#
#
# Place
#
# NumWebPurchases: Number of purchases made through the company’s web site
#
# NumCatalogPurchases: Number of purchases made using a catalogue
#
# NumStorePurchases: Number of purchases made directly in stores
#
# NumWebVisitsMonth: Number of visits to company’s web site in the last month
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# <a name="Focus"></a>
# ## Focus on the Questions
#
# * Restate the Prediction Problems and Basic Questions.
#
# * Discuss the reasons each is of interest.
#
# * Discuss any difficulties that you can forsee in moving towards a solution.
#
# * Talk about the features / columns that will be essential to your exploration.
#
# ---
# I predict that the amount of wine purchased can help determine if there are children in the home.
#
# MntWines, Kidhome, & Teenhome will be used to resolve this
#
# I think we all know the answer.
#
# ---
# I Predict that the amount of wine purchased and/or the total purchases will indicate the income of the customer.
#
# MntWines, TotalPurchases, & Income will be used to resolve this
#
# It is very likely that the income of a customer will correlate to  how much overll they can purchase as well as how much they can spend on a luxury item like wine.
#
# ---
# How often does an average family shop at this store?
#
# Recency, Marital_Status, Income, Kidhome, & Teenhome would be used to resolve this.
#
# It would be interesting to know if married couples or people with children in the home can find the time to shop as frequently as single people.
#
# ---
# Which type of customer takes the most advantage of deals?
#
# Year_Birth, Education, Marital_Status, Income, Teenhome, Kidhome, NumDealsPurchases, & TotalPurchases would be used to resolve this.
#
# It would be beneficial for the store to know who their deals are reaching so they can further cater to that audience or change something to grab a new audience.
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# <a name="Explore"></a>
# ## Data Exploration
#
# * Use .info to determine if there is any missing data. If so, make the decision (with a brief explanation) of how you will handle it (drop rows, fill with avg values, other options).
#
# * Use .describe to determine if there are any outliers, and get a general feel for the distribution of each column.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %%
#Checking the info around the columns to see missinng values as well as the type for the data.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Used the .dropna() method to remove the null values from our Income column

df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   object
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %%
#Checking the describe for all columns to see any outliers or intereting data points.

df.describe()
# Out:
#                  ID   Year_Birth  ...  Z_Revenue     Response
# count   2216.000000  2216.000000  ...     2216.0  2216.000000
# mean    5588.353339  1968.820397  ...       11.0     0.150271
# std     3249.376275    11.985554  ...        0.0     0.357417
# min        0.000000  1893.000000  ...       11.0     0.000000
# 25%     2814.750000  1959.000000  ...       11.0     0.000000
# 50%     5458.500000  1970.000000  ...       11.0     0.000000
# 75%     8421.750000  1977.000000  ...       11.0     0.000000
# max    11191.000000  1996.000000  ...       11.0     1.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# Take the time to make simple notes about your findings from your exploration.
#
# What are you learning about your dataset?
#
# There is at least 1 really low household income reported, hopefully they thought it was asking for monthly.
#
# We don't have very large families, no more than 2 children in a household.
#
# We have at least one VERY old customer (it's 3 but i only know that from later on)

# %% [markdown]
# <a name="Continue"></a>
# ## Continue the Exploration
# * Use .unique to ensure that the values in the columns are as you would expect. If not, make necessary decisions/changes.
#
# * View the each of the key columns and ensure they are clean and in the format that will be most help for you.
#
# * If needed, make alterations to columns using methods such as .str.split(), .astype(), etc.
#
# * If necessary, create new columns based upon other columns in the dataframe (again) to aid in the solution/answers to your questions.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %%
#confirming the ID can be used as a unique identifer if needed.
#No names or anything to go on for identification here.

df['ID'].is_unique
# Out:
# True

# %%
#Combining the different purchase types into one column in order to easier study the deals purchases vs overall purchases to find the percentage a customer used.

df['TotalPurchases'] = df['NumWebPurchases'] + df['NumStorePurchases'] + df['NumCatalogPurchases']
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          ID  Year_Birth   Education  ... Z_Revenue  Response  TotalPurchases
# 0      5524        1957  Graduation  ...        11         1              22
# 1      2174        1954  Graduation  ...        11         0               4
# 2      4141        1965  Graduation  ...        11         0              20
# 3      6182        1984  Graduation  ...        11         0               6
# 4      5324        1981         PhD  ...        11         0              14
# ...     ...         ...         ...  ...       ...       ...             ...
# ...

# %% [markdown]
# Take the time to make simple notes about your findings from your exploration.
#
# What are you learning about your dataset?
#
# Still feel okay about our data. We know there are some outliers to look our for but confident we can work around it.

# %% [markdown]
# <a name="Visualizations"></a>
# ## Initial Visualizations
#
# (For bar charts see Notebook #1, #2, and #4. For histograms see Notebook #2.
#
# Use simple bar charts and histograms to explore the contents and distributions of key columns in your data set.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %%
#Checking to see if marital status has an effect on number of deals claimed.
#YOLO is surprisingly aware of deals. They may throw caution to the wind but not when it comes to saving money.

fig = plot.subplots(figsize = (10,6))

plot.scatter(x = df['Marital_Status'], 
         y = df['NumDealsPurchases'],
           alpha = 0.75, )

plot.xlabel('Marital Status')
plot.ylabel('Purchased Deals')
# Out:
# Text(0, 0.5, 'Purchased Deals')

# %%
#Interested to see the overall number of teens and kids in the home.
#This confirms what we found in the describe in that there are not really large families accounted for.

fig = df['Kidhome'].plot.hist(figsize = (10,4))
fig = df['Teenhome'].plot.hist(figsize = (10,4), alpha = .7)
fig.set_title('Number of Children in the Home', fontweight = 'bold');

# %%
#Finding the spread of income while filtering out a large outlier.

fig = df.loc[df['Income']< 200000]['Income'].plot.hist(figsize = (10,4), bins = 75)
fig.set_title('Household Income', fontweight = 'bold');

# %%
#Checking to see if having children or teens in the home have an effect on wine purchased.
#Overall, this seems like it does not but we can notice that having 2 teens does make you more likely to buy wine than having 2 kids.

fig = plot.subplots(figsize = (10,6))

plot.scatter(x = df['Kidhome'], 
         y = df['MntWines'],
           alpha = 0.75, )

plot.scatter(x = df['Teenhome'], 
         y = df['MntWines'],
           alpha = 0.75, )

plot.xlabel('# Children in the Home')
plot.ylabel('Wine Purchased')
# Out:
# Text(0, 0.5, 'Wine Purchased')

# %%
#Came back to this after a later chart was created to make the data present better.
#The dfDeals dataframe has the large income reported removed.
#From this you can see that the middle incomes tend to take advantage of deals more often.

fig = plot.subplots(figsize = (10,6))

plot.scatter(x = dfDeals['NumDealsPurchases'], 
         y = dfDeals['Income'],
           alpha = 0.75, )

plot.xlabel('Purchased Deals')
plot.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %% [markdown]
# Take the time to make simple notes about your findings from your exploration.
#
# What are you learning about your dataset?
#
# I kind of reported as I went.
# However one thing I noticed is that a lot of the data points I am interested in don't have a lot of buckets to fall into like the kidhome and teenhome so it's hard to find my answers from graphs alone.

# %% [markdown]
# <a name="Basic"></a>
# ## Revisit your Basic Questions
#
# In the text cells below, you should build an outline for the necessary steps the must be taken (with the data) to answer each question.
#
# Most likely, you will need to take advantage of the pandas methods you have learned over the past several weeks to move closer to your goals.
#
# **Take the time to consider:**
#
# Methods such as value_counts() and sort_values(), as well as ...
#
# **Filtering**
# (See Notebook #2)
#
# newDf = df[df['column_name'] <= 35]
#
# df['newColumn'] = df.loc[df['column_name'] == 35]['another_column'].str.split()[1]
#
# **Groupby and/or Agg**
# (See Notebook #3 and #4)
#
# dfGroup = df.groupby('column_name')['another_column_for_values'].mean()
#
# dfGroupAgg = df.groupby(['column_name','second_column])[['col1','col2','col3']].agg(['mean','median'])
#
# **Or even a Pivot table**
# (See Notebook #4)
#
# dfPivot = df.pivot(index = 'Column_For_Index',
#                                 columns='Categorical_Column_For_Columns', values='Column_For_Values')
#
# **And if you have the need to combine two dataframes by simply stacking them vertically or horizontally ... you may have the need to use concatenation:**
# (See Notebook #4)
#
# dfLarge = pd.concat([df1,df2,df3], axis=1) # to stack horizontally or
#
# dfLarge = pd.concat([df1,df2,df3], axis=0).reset_index() # to stack vertically.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# ### Question 1 Outline:
#
# ### Your work here ...

# %%
# Solve question 1: Which type of customer takes the most advantage of deals?

# %%
#Creating the dfDeals dataframe to just include the columns I am interested in for this question.

dfDeals = df[['ID', 'Year_Birth', 'Education','Marital_Status', 'Income', 'Teenhome', 'Kidhome', 'NumDealsPurchases', 'TotalPurchases']].copy()
dfDeals
# Out:
#          ID  Year_Birth   Education  ... Kidhome  NumDealsPurchases  TotalPurchases
# 0      5524        1957  Graduation  ...       0                  3              22
# 1      2174        1954  Graduation  ...       1                  2               4
# 2      4141        1965  Graduation  ...       0                  1              20
# 3      6182        1984  Graduation  ...       1                  2               6
# 4      5324        1981         PhD  ...       1                  5              14
# ...     ...         ...         ...  ...     ...                ...             ...
# 2235  10870        1967  Graduation  ...       0                  2              16
# 2236   4001        1946         PhD  ...       2                  7              15
# 2237   7270        1981  Graduation  ...       0                  1              18
# 2238   8235        1956      Master  ...       0                  2              21
# ...

# %%
#Updating the chart above to remove the outlier income.

dfDeals = dfDeals[dfDeals['Income']<200000]
dfDeals
# Out:
#          ID  Year_Birth   Education  ... Kidhome  NumDealsPurchases  TotalPurchases
# 0      5524        1957  Graduation  ...       0                  3              22
# 1      2174        1954  Graduation  ...       1                  2               4
# 2      4141        1965  Graduation  ...       0                  1              20
# 3      6182        1984  Graduation  ...       1                  2               6
# 4      5324        1981         PhD  ...       1                  5              14
# ...     ...         ...         ...  ...     ...                ...             ...
# 2235  10870        1967  Graduation  ...       0                  2              16
# 2236   4001        1946         PhD  ...       2                  7              15
# 2237   7270        1981  Graduation  ...       0                  1              18
# 2238   8235        1956      Master  ...       0                  2              21
# ...

# %%
#Checking the .describe to make sure it was successfully removed.

dfDeals['Income'].describe()
# Out:
# count      2215.000000
# mean      51969.861400
# std       21526.320095
# min        1730.000000
# 25%       35284.000000
# 50%       51373.000000
# 75%       68487.000000
# max      162397.000000
# Name: Income, dtype: float64

# %%
#Doing the same thing for some outlier birth years. We had a couple pre 1900 which seems unlikely.

dfDeals = dfDeals[dfDeals['Year_Birth']>1940]
dfDeals
# Out:
#          ID  Year_Birth   Education  ... Kidhome  NumDealsPurchases  TotalPurchases
# 0      5524        1957  Graduation  ...       0                  3              22
# 1      2174        1954  Graduation  ...       1                  2               4
# 2      4141        1965  Graduation  ...       0                  1              20
# 3      6182        1984  Graduation  ...       1                  2               6
# 4      5324        1981         PhD  ...       1                  5              14
# ...     ...         ...         ...  ...     ...                ...             ...
# 2235  10870        1967  Graduation  ...       0                  2              16
# 2236   4001        1946         PhD  ...       2                  7              15
# 2237   7270        1981  Graduation  ...       0                  1              18
# 2238   8235        1956      Master  ...       0                  2              21
# ...

# %%
#Checking to make sure that the dates were filtered as expecteed.

dfDeals['Year_Birth'].describe()
# Out:
# count    2211.000000
# mean     1968.926730
# std        11.688067
# min      1941.000000
# 25%      1959.000000
# 50%      1970.000000
# 75%      1977.000000
# max      1996.000000
# Name: Year_Birth, dtype: float64

# %%
#Sorted the chart to bring the highest number of deal purchasses to the top for a quick snapshot of who is claiming the most.

dfDeals.sort_values("NumDealsPurchases", axis = 0, ascending = False,
                 inplace = True, na_position ='first')
dfDeals.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#          ID  Year_Birth   Education  ... Kidhome  NumDealsPurchases  TotalPurchases
# 1846   9931        1963         PhD  ...       1                 15               0
# 687    1501        1982         PhD  ...       0                 15              29
# 1245   6862        1971  Graduation  ...       0                 15               0
# 1042  10749        1991  Graduation  ...       0                 15               1
# 164    8475        1973         PhD  ...       0                 15              22
# 21     5376        1979  Graduation  ...       1                 15              28
# ...

# %%
#Updating this chart to remove anyone who did not take advantage of any deals.

dfDeals = dfDeals[dfDeals['NumDealsPurchases']>=1]
dfDeals.sample(10)
# Out:
#          ID  Year_Birth   Education  ... Kidhome  NumDealsPurchases  TotalPurchases
# 2002   4023        1970  Graduation  ...       1                  3               7
# 244    6439        1958  Graduation  ...       0                  7              24
# 772    8897        1965  Graduation  ...       1                  8              17
# 1498   9463        1959  Graduation  ...       0                  4              21
# 2225   4749        1968  Graduation  ...       1                  6              16
# 472     564        1981         PhD  ...       1                  7              23
# 1042  10749        1991  Graduation  ...       0                 15               1
# 1256   9094        1955    2n Cycle  ...       0                  2              14
# 1572   5350        1991      Master  ...       0                  1              17
# 1643   3829        1979       Basic  ...       1                  1               4
#
# [10 rows x 9 columns]

# %%
#In this cell you can use the .value_counts method to see how many deals each different classification is taking advantage of.
#Found that Birth Year was not a great option for this.

#dfDeals['Marital_Status'].value_counts()
#dfDeals['Year_Birth'].value_counts()
dfDeals['Education'].value_counts()
# Out:
# Graduation    1093
# PhD            466
# Master         358
# 2n Cycle       196
# Basic           54
# Name: Education, dtype: int64

# %%
#Visualization for how birth year effects the number of deals you take advantage of.
#Seems like people born between about 1955 and 1980 took the best advantage of deals, but not by that wide of a margin.

#Probably the best way to display deals compared to birth year.

fig = plot.subplots(figsize = (20,6))

plot.scatter(x = dfDeals['Year_Birth'], 
         y = dfDeals['NumDealsPurchases'],
           alpha = 0.75, )

plot.xlabel('Birth Year')
plot.ylabel('Purchased Deals')
# Out:
# Text(0, 0.5, 'Purchased Deals')

# %%
#Simple chart showing total number of deals claimed by marital status.
#Finding that couples and married folks are claiming significantly more deals.

fig = dfDeals['Marital_Status'].value_counts().plot.bar(figsize = (15,10), width = 0.8,color = 'orange')
fig.set_xlabel('Marital Status')
fig.set_ylabel('Counts')
fig.set_title('Number of deals claimed by Marital Status#', fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Number of deals claimed by Marital Status#')

# %%
#Quick scatterplot showing the number of deals claimed by income level.
#Same findings as earlier in the initial exploration. The middle incomes tend to take the most advantage of deals.

fig = plot.subplots(figsize = (20,6))

plot.scatter(x = dfDeals['Income'], 
         y = dfDeals['NumDealsPurchases'],
           alpha = 0.75, )

plot.xlabel('Income')
plot.ylabel('Purchased Deals')
# Out:
# Text(0, 0.5, 'Purchased Deals')

# %% [markdown]
# ### Question 2 Outline:
#
# ### Your work here ...

# %%
# Solve question 2: How often does an average family shop at this store?

# %%
#Creating a dataframe with just the columns we expect to need for this question.

dfRecent = df[['Marital_Status', 'Income', 'Kidhome', 'Teenhome', 'Recency']].copy()
dfRecent
# Out:
#      Marital_Status   Income  Kidhome  Teenhome  Recency
# 0            Single  58138.0        0         0       58
# 1            Single  46344.0        1         1       38
# 2          Together  71613.0        0         0       26
# 3          Together  26646.0        1         0       26
# 4           Married  58293.0        1         0       94
# ...             ...      ...      ...       ...      ...
# 2235        Married  61223.0        0         1       46
# 2236       Together  64014.0        2         1       56
# 2237       Divorced  56981.0        0         0       91
# 2238       Together  69245.0        0         1        8
# 2239        Married  52869.0        1         1       40
#
# [2216 rows x 5 columns]

# %%
#Grouped the marital statuses and identified the mean value for income and receny to get a quick snapshot of what to expect.

dfRecent.groupby('Marital_Status').mean()
# Out:
#                       Income   Kidhome  Teenhome    Recency
# Marital_Status
# Absurd          72365.500000  0.000000  0.000000  53.000000
# Alone           43789.000000  1.000000  0.666667  30.333333
# Divorced        52834.228448  0.413793  0.590517  49.487069
# Married         51724.978996  0.453909  0.511085  48.310385
# Single          50995.350318  0.456476  0.401274  49.199575
# Together        53245.534031  0.450262  0.528796  49.989529
# Widow           56481.552632  0.236842  0.644737  48.802632
# YOLO            48432.000000  0.000000  1.000000   3.000000

# %%
#Decided to check the same to see how having a kidhome or a teenhome effected this.

dfRecent.groupby('Kidhome').mean()
#dfRecent.groupby('Teenhome').mean()
# Out:
#                Income  Teenhome    Recency
# Kidhome
# 0        61779.858145  0.530008  48.836321
# 1        39138.076663  0.463360  49.076663
# 2        39149.500000  0.630435  52.695652

# %%
#A scatterplot to display findings for marital status compared to how often they shop.
#This is one of the times that having so few buckets was a bit of a detriment, however the mean from the previous cells is probably the best to refernce for answering the question.

fig = plot.subplots(figsize = (20,6))

plot.scatter(x = dfRecent['Marital_Status'], 
         y = dfRecent['Recency'],
           alpha = 0.75, )

plot.xlabel('Marital_Status')
plot.ylabel('Recency')
# Out:
# Text(0, 0.5, 'Recency')

# %% [markdown]
# ### Question 3 Outline:
#
# ### Your work here ...

# %%
# Solve question 3:

# %% [markdown]
# <a name="Prediction"></a>
# ## Revisit your Prediction Problems
#
# You should have two Prediction Questions:
# * The first involves the prediction of a continuous/measureable value from your data set. This will be the **Target** for your **ML Regression Models**.
# * The second focuses on the prediction of a categorical value from your data set. This will be the **Target** for your **ML Classification Models**.
#
# ---
# I predict that the amount of wine purchased can help determine if there are children in the home.
#
# Having gone through the data a bit, I am less sure that the amount of wine being purchased is higher for people with kids as we thought. However this does mean the ML should have an easy time determining who does not have kids and purchases a lot of wine so we will see.
#
# ---
# I Predict that the amount of wine purchased and/or the total purchases will indicate the income of the customer.
#
# This is kind of a basic question but we needed to find good continuous data to use and after referncing the SNS scatterplots these seemed like the best to achieve a high score.
#
# ---
# I predict that the number of deals purchased will help the ML determine the education level of a customer.
#
# It seems to me that there should be a decent enough correlation here to allow the machine learning to make accurate predictions.
#
#
#
# * Restate your expectations and/or hypotheses for the outcome of the ML process below:
#
#
#
#
#
#
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# <a name="Seaborn"></a>
# ## Additional visualizations with Seaborn pairplots to help determine which features may be most helpful in predicting your target value in the Machine Learning process to follow.
# (See Notebook #6 and #7)
#
#
#
#
#
# [Back to Table of Contents](#Contents)

# %%
#this is the SNS pairplot for all the different columns I thought were interesting or could possibly correlate.
#included the filter for the outlier salary and birth years.

import seaborn as sns

df = df[['Year_Birth','Education','Marital_Status','Income','Teenhome','Kidhome','Recency','MntWines','NumWebPurchases','NumStorePurchases','NumCatalogPurchases','NumDealsPurchases','TotalPurchases']].copy()

df = df[df['Year_Birth']>1940]
df = df[df['Income']<200000]


sns.pairplot(df[['Year_Birth','Education','Marital_Status','Income','Teenhome','Kidhome','Recency','MntWines','NumWebPurchases','NumStorePurchases','NumCatalogPurchases','NumDealsPurchases','TotalPurchases']])

# %% [markdown]
# <a name="ML"></a>
# ## Let's begin the Machine Learning Process.
# (See Notebooks #6, #7, and #8)
#
#
#
#
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# <a name="Regression"></a>
# ### 1) Choose the Features and a Target for your Regression problem.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %%
#Built this code in order to classify the income levels if needed.

'''
count      2215.000000
mean      51969.861400
std       21526.320095
min        1730.000000
25%       35284.000000
50%       51373.000000
75%       68487.000000
max      162397.000000
Name: Income, dtype: float64
'''
'''
df['SMLXL'] = 3

df.loc[df['Income']<=68487,'SMLXL']= 2
df.loc[df['Income']<=51373,'SMLXL']= 1
df.loc[df['Income']<=35284,'SMLXL']= 0

df[['Income','SMLXL']].sample(20)
# Out:
#   File "<ipython-input-34-bab88c6545d6>", line 21
#     df[['Income','SMLXL']].sample(20)
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
# Features
X = df[['TotalPurchases']]

# Target
y = df['Income']

# %% [markdown]
# Give a brief explanation about why/how you chose your features.
#
# Experiment with various features combinations to determine the 'best' choices.
#
# Give a brief account of your process.
#
#
# We determine it was likely that total purchases would correlate fairly closely (or at least closely for this dataset) to achieve a high score.

# %% [markdown]
# ### 2) Create Training and Testing sets

# %%
from sklearn.model_selection import train_test_split

# The code below splits our X and y into training and testing sets. 
# Since test_size=0.20, the split will be 80% Training to 20% Testing sets.
# Kept the random state so we could compare results.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %% [markdown]
# ### 3) Feature Scaling

# %%
# We now transform our feature values to the number
# of Standard Deviations each value is from its mean.

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

X_train[:5]
# Out:
# array([[-0.49737896],
#        [ 0.05559447],
#        [ 0.19383783],
#        [ 0.88505462],
#        [-0.91210903]])

# %% [markdown]
# Give a brief explanation for why feature scaling may (or may not) be beneficial (or even essential) with your specific dataset and features.
#
# In the case of our data I don't believe the values are large enough for scaling to help. It would likely be more of a detriment.
#
# Some of us used feature scaling and we found it did not have an effect on the results. It is likely because the total purchases do not vary too widely.
#
# As an example, if we wanted to scale the income levels for a different question, that would be a good candidate for scaling.

# %% [markdown]
# ## Simple Linear Regression: Select, Instantiate, Fit, Score

# %%
## Select/Import the Model.
    
from sklearn import linear_model
    
## Instantiate the Linear Regression model. 
LinMod = linear_model.LinearRegression()

## Fit the model on the training data.
LinMod.fit(X_train, y_train)
    
## See how the model performs on the test data.
LinMod.score(X_test, y_test)
# Out:
# 0.6252562474071042

# %% [markdown]
# ### Simple Linear Regression: Evaluate ... ScatterPlots

# %%
# Predicted values of y based upon the model

y_pred = LinMod.predict(X_test)

plot.scatter(X_test, y_test,  color='black')
plot.scatter(X_test, y_pred, color='blue',  alpha=0.3)
plot.xlabel('TotalPurchases')
plot.ylabel('Income')
plot.show()

# %% [markdown]
# ## Multiple Linear Regression: Select, Instantiate, Fit, Score

# %%
# Features
X = df[['MntWines','TotalPurchases']]

# Target
y = df['Income']

# %%
from sklearn.model_selection import train_test_split

# The code below splits our X and y into training and testing sets. 
# Since test_size=0.20, the split will be 80% Training to 20% Testing sets.
# Kept the random state so we could compare results.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

X_train[:5]
# Out:
# array([[ 2.41894153, -0.49737896],
#        [-0.80646222,  0.05559447],
#        [ 0.03118885,  0.19383783],
#        [ 1.86150114,  0.88505462],
#        [-0.78559547, -0.91210903]])

# %%
from sklearn import linear_model

## Instantiate the Linear Regression model. 
MLR = linear_model.LinearRegression()

## Fit the model on the training data.
MLR.fit(X_train, y_train)
    
## See how the model performs on the test data.
MLR.score(X_test, y_test)
# Out:
# 0.6554466296565562

# %% [markdown]
# ### Multiple Linear Regression: Evaluate ... ScatterPlots

# %%
r_sq = MLR.score(X_test, y_test)
print('coefficient of determination:', r_sq)

print('intercept:', MLR.intercept_)

print('slope:', MLR.coef_)
# Out:
# coefficient of determination: 0.6554466296565562
# intercept: 51999.659502262446
# slope: [ 6464.75300403 11049.76150102]

# %%
#Predicted values of y based upon the model
y_pred = MLR.predict(X_test)
# Use scatter plots if helpful to show test vs predicted values.

plot.scatter(X_test[:,0], y_test,  color='black')
plot.scatter(X_test[:,0], y_pred, color='blue',  alpha=0.3)
plot.xlabel('MntWines')
plot.ylabel('Income')
plot.show()

plot.scatter(X_test[:,1], y_test,  color='black')
plot.scatter(X_test[:,1], y_pred, color='blue',  alpha=0.3)
plot.xlabel('TotalPurchases')
plot.ylabel('Income')
plot.show()

from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

fig = pyplot.figure()
ax = Axes3D(fig)

ax.scatter(X_test[:,0],X_test[:,1], y_test,  color='black')
ax.scatter(X_test[:,0],X_test[:,1], y_pred,  color='blue')
pyplot.show()

# %% [markdown]
# ## K Nearest Neighbors: Select, Instantiate, Fit, Score

# %%
## Select/Import the Model.
    
from sklearn.neighbors import KNeighborsRegressor
    
## Instantiate the Knn model with ... neighbors. 
KNN = KNeighborsRegressor(n_neighbors=7)
    
## Fit the model on the training data.
KNN.fit(X_train, y_train)
    
## See how the model performs on the test data.
KNN.score(X_test, y_test)
# Out:
# 0.7334782998351805

# %% [markdown]
# Take the time to find the 'best' number of neighbors.
#
# Give a brief account of your process.
#
# Started with a low number of neighbors but that surprisingly gave worse results than neighbors around 10.

# %% [markdown]
# ###K Nearest Neighbors: Evaluate ... ScatterPlots

# %%
# Predicted values of y based upon the model

y_pred = KNN.predict(X_test)

from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

fig = pyplot.figure()
ax = Axes3D(fig)

ax.scatter(X_test[:,0],X_test[:,1], y_test,  color='black')
ax.scatter(X_test[:,0],X_test[:,1], y_pred,  color='blue')
pyplot.show()

# %% [markdown]
# ##Random Forest: Select, Instantiate, Fit, Score

# %%
## Select/Import the Model.

from sklearn.ensemble import RandomForestRegressor

## Instantiate the Random Forest model
RF = RandomForestRegressor(n_estimators=19)

## Fit the model on the training data.
RF.fit(X_train, y_train)

## See how the model performs on the test data.
print(RF.score(X_test, y_test))
# Out:
# 0.7082805822709116

# %% [markdown]
# Take the time to find the 'best' number of estimates.
#
# Give a brief account of your process.
#
# Found that around 2 and 20 gave the best results.

# %% [markdown]
# ### Random Forest: Evaluate ... ScatterPlots

# %%
# Predicted values of y based upon the model
y_pred = RF.predict(X_test)

from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

fig = pyplot.figure()
ax = Axes3D(fig)

ax.scatter(X_test[:,0],X_test[:,1], y_test,  color='black')
ax.scatter(X_test[:,0],X_test[:,1], y_pred,  color='blue')
pyplot.show()

# %% [markdown]
# <a name="Classification"></a>
# ## Move on to consider the **Classification** models.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# ### 1) Choose the Features and a Target for your problem.

# %%
# Define the features and the target from your dataset.

# Features
X = df[['NumDealsPurchases']]

# Target
y = df['Education']

# %% [markdown]
# Give a brief explanation about why/how you chose your features.
#
# Experiment with various features combinations to determine the 'best' choices.
#
# Give a brief account of your process.
#
# Essentialy the idea was that people with a higher level of education would take better advantage of deals or at least the learning would be able to determine education level by deals accepted.
#
# Tested income because I thought that may also be a good indicater but it turned out to be slightly worse overall.

# %% [markdown]
# ### 2) Create Training and Testing sets
#
# *   List item
# *   List item

# %%
# import the package to create the Training and Testing split.

from sklearn.model_selection import train_test_split

# The code below splits our X and y into training and testing sets. 
# Since test_size=0.30, the split will be 70% Training to 30% Testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=2)

# %% [markdown]
# ### 3) Feature Scaling

# %% [markdown]
# Give a brief explanation for why feature scaling may (or may not) be beneficial (or even essential) with your specific dataset and features.
#
# Same as before. We are not dealing with partiuclarly varied numbers here so scaling would be unnecessary.

# %% [markdown]
# ## K Nearest Neighbors: Select, Instantiate, Fit, Score

# %%
## Select/Import the Model.
    
from sklearn.neighbors import KNeighborsClassifier
    
## Instantiate the Knn model with ... neighbors. 
KNN = KNeighborsClassifier(n_neighbors=10)
    
## Fit the model on the training data.
KNN.fit(X_train, y_train)
    
## See how the model performs on the test data.
KNN.score(X_test, y_test)
# Out:
# 0.5

# %% [markdown]
# Take the time to find the 'best' number of neighbors.
#
# Give a brief account of your process.
#
# Less neighbors received notably worse results. .27 at 2. 10 seemed to be where it peaked.

# %% [markdown]
# ###K Nearest Neighbors: Evaluate ... Classification Report

# %%
# Predicted values of y based upon the model

y_pred = KNN.predict(X_test)

# The classification report shows how well the model performed on each possible outcome
# or CityNum in our case.
from sklearn.metrics import classification_report  

# The classification report compares what was predicted for the test set  
# against what was actually seen in the test set.
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     2n Cycle       0.00      0.00      0.00        97
#        Basic       0.00      0.00      0.00        26
#   Graduation       0.50      0.99      0.67       558
#       Master       0.09      0.01      0.01       181
#          PhD       0.00      0.00      0.00       244
#
#     accuracy                           0.50      1106
#    macro avg       0.12      0.20      0.14      1106
# weighted avg       0.27      0.50      0.34      1106
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Offer a brief interpretation of the classification report.
#
# Because there were a large number of 'Graduation' results, it seems like the program defaulted to that a lot. getting 50% of the ones it attempted to classify as graduation correct but 99% of the actual 'Graduation' classifications were sorted correctly.

# %% [markdown]
# ##Random Forest: Select, Instantiate, Fit, Score

# %%
## Select/Import the Model.

from sklearn.ensemble import RandomForestClassifier

## Instantiate the Random Forest model
RF = RandomForestClassifier(n_estimators=3)

## Fit the model on the training data.
RF.fit(X_train, y_train)

## See how the model performs on the test data.
print(RF.score(X_test, y_test))
# Out:
# 0.5009041591320073

# %% [markdown]
# Take the time to find the 'best' number of estimates.
#
# Give a brief account of your process.
#
# Tried some numbers between 2 and 10 and noticeed it trended a little better around 3.

# %% [markdown]
# ### Random Forest: Evaluate ... Classification Report

# %%
# Predicted values of y based upon the model

y_pred = RF.predict(X_test)

# The classification report shows how well the model performed on each possible outcome
# or CityNum in our case.
from sklearn.metrics import classification_report  

# The classification report compares what was predicted for the test set  
# against what was actually seen in the test set.
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     2n Cycle       0.00      0.00      0.00        97
#        Basic       0.00      0.00      0.00        26
#   Graduation       0.50      0.99      0.67       558
#       Master       0.00      0.00      0.00       181
#          PhD       0.30      0.01      0.02       244
#
#     accuracy                           0.50      1106
#    macro avg       0.16      0.20      0.14      1106
# weighted avg       0.32      0.50      0.34      1106
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Created a classification bucket for people with at least 1 child and people with none.
# 0 = none and 1 = at least 1

df['Children'] = 0

df.loc[df['Kidhome']>0,'Children']= 1
df.loc[df['Teenhome']>0,'Children']= 1

df[['Kidhome','Teenhome','Children']].sample(10)
# Out:
#       Kidhome  Teenhome  Children
# 1674        0         1         1
# 1447        0         1         1
# 1247        1         1         1
# 702         0         1         1
# 1439        1         0         1
# 1667        1         1         1
# 571         1         1         1
# 595         1         0         1
# 690         0         1         1
# 1388        1         1         1

# %%
# Define the features and the target from your dataset.

# Features
X = df[['MntWines']]

# Target
y = df['Children']

# %%
# import the package to create the Training and Testing split.

from sklearn.model_selection import train_test_split

# The code below splits our X and y into training and testing sets. 
# Since test_size=0.30, the split will be 70% Training to 30% Testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=2)

# %%
## Instantiate the Knn model with ... neighbors. 
KNN = KNeighborsClassifier(n_neighbors=10)
    
## Fit the model on the training data.
KNN.fit(X_train, y_train)
    
## See how the model performs on the test data.
KNN.score(X_test, y_test)
# Out:
# 0.7003012048192772

# %%
# Predicted values of y based upon the model

y_pred = KNN.predict(X_test)

# The classification report shows how well the model performed on each possible outcome
# or Children in our case.

# The classification report compares what was predicted for the test set  
# against what was actually seen in the test set.
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.35      0.40       189
#            1       0.76      0.84      0.80       475
#
#     accuracy                           0.70       664
#    macro avg       0.61      0.59      0.60       664
# weighted avg       0.68      0.70      0.69       664

# %%
RF = RandomForestClassifier(n_estimators=3)

## Fit the model on the training data.
RF.fit(X_train, y_train)

## See how the model performs on the test data.
print(RF.score(X_test, y_test))
# Out:
# 0.697289156626506

# %%
# Predicted values of y based upon the model

y_pred = RF.predict(X_test)

# The classification report shows how well the model performed on each possible outcome
# or Children in our case.

# The classification report compares what was predicted for the test set  
# against what was actually seen in the test set.
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.37      0.41       189
#            1       0.77      0.83      0.80       475
#
#     accuracy                           0.70       664
#    macro avg       0.61      0.60      0.60       664
# weighted avg       0.68      0.70      0.69       664

# %% [markdown]
# Offer a brief interpretation of the classification report.
#
# In both reports it seems like the program was able to identify a lot of the with children results correctly. That could be attributed to the fact that there were a lot more results for that option.
#
# Different to the previous one it did also attempt to put some into the no children bucket. It was not as accurate as the with children but interesting to see it attempt choosing both.

# %% [markdown]
# <a name="Results"></a>
# ## Communicate the Results

# %% [markdown]
# ### We must always start by going back to our question/problem. Perhaps just as importantly, we need to ensure that we have our audience in mind.
#
# ### What have we learned about our ability to determine the answers to your questions and/or solutions to your problems?
#
# I think we determined that our dataset was not as varied or clean as we may have liked it to be to achieve the best results.
#
# The fields we thought we could pull some interesting insight from ended up being failry limited.
#
# I think we were surprised that families with kids drink just about as much as families without.
#
# ### And who are we reporting to? Our story may be different if our concern is for the typical customer ... or perhaps for specific internal user. Be clear about who you are addressing and what message/result you have for them.
#
# Overall we are communicating to you, our teacher, but I believe we also chose some questons and researched some topics that would be useful to the client (store) as well.
#
# I don't think we had any data points that would have been particularly useful to us on a personal level. Maybe if we had info about how often they run sales or something like taht we could determine the best days or times of year to shop there.
#
# ### Again, our focus should be on our results and the possible impact on our audience rather than the fascination that we may have (or not) with our own explorations and machine learning models.
#
# ### What can our audience learn and what action can take from the results that we have to offer.
#
# One of the main actionable items we determined was that their deals are reaching married families and couples the most. The store could focus in on that demographic or potential alter how they advertise to try and bring in the others as well.
#
# ### If your results are not as complete or enlightening as you would have hoped, say so ... and talk about possible next steps for working towards better solutions based upon data needs ... or perhaps even the admission that the work has shown that further work may not be as advantageous as first anticipated.
#
# I believe with the dataset we have there isn't a whole lot more to learn. The best attribute of our data are probaly the deals as well as the total purchases column we made.
#
# It would be possible to go a little further and determine which of their sales methods are the most successful between online, store, and catalog.
#
# I would have liked for the complaints column to have been total number of complaints rather than just if they complained or not ever. With that we could ahve determined which customer type complains the most and see if the business can adjust to deal with that.
#
#
#
#
# [Back to Table of Contents](#Contents)

# %% [markdown]
# ## The story of your results here ...
